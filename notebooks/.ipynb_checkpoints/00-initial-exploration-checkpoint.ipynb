# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,scipy,sklearn,pandas
# Out:
# Sat Jun 29 2019
#
# CPython 3.7.3
# IPython 7.4.0
#
# numpy 1.16.2
# scipy 1.2.1
# sklearn 0.20.3
# pandas 0.24.2
#
# compiler   : Clang 6.0 (clang-600.0.57)
# system     : Darwin
# release    : 18.6.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 8
# interpreter: 64bit

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
# Out:
# /Users/ylmrdm/mlio

# %%
pd.show_versions(as_json=False)
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
#
# pandas: 0.24.2
# pytest: 4.4.1
# pip: 19.1.1
# setuptools: 40.8.0
# Cython: None
# numpy: 1.16.2
# scipy: 1.2.1
# pyarrow: None
# xarray: None
# IPython: 7.4.0
# sphinx: None
# patsy: 0.5.1
# dateutil: 2.8.0
# pytz: 2018.9
# blosc: None
# bottleneck: None
# tables: None
# numexpr: None
# feather: None
# matplotlib: 3.0.3
# openpyxl: 2.6.2
# xlrd: 1.2.0
# xlwt: None
# xlsxwriter: 1.1.8
# lxml.etree: None
# bs4: None
# html5lib: None
# sqlalchemy: None
# pymysql: None
# psycopg2: None
# jinja2: None
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None
# gcsfs: None

# %%
data = os.path.join(PROJ_ROOT, 'data', 'preprocessed', 'data.csv')
df = pd.read_csv(data)
df.head()
# Out:
#     pid              time operation  operation_label  \
# 0  8703  1525430073780920      read                2
# 1  8703  1525430073781000      read                2
# 2  8703  1525430073781060      read                2
# 3  8703  1525430073781120      read                2
# 4  8703  1525430073781200      read                2
#
#                                                 path  idfile    rs size error  \
# 0   \1\0\0\0\377\377\377\377\377\377\377\377\377\...     821  32.0   32   NaN
# 1                                           \\\0\0\0     821   4.0    4   NaN
# 2                                           \n\0\0\0     821   4.0    4   NaN
# 3                                        --version\0       7  10.0   10   NaN
# 4                                           \6\0\0\0       7   4.0    4   NaN
#
#    error_label flag
# 0            0  NaN
# 1            0  NaN
# 2            0  NaN
# 3            0  NaN
# 4            0  NaN

# %%
df.columns
# Out:
# Index(['pid', 'time', 'operation', 'operation_label', 'path', 'idfile', 'rs',
#        'size', 'error', 'error_label', 'flag'],
#       dtype='object')

# %%
sns.FacetGrid(df, hue="error_label", height=15).map(sns.distplot, "operation_label").add_legend()

# %%
df_filtered = df[df['error_label'] == 0]
df_filtered.shape
# Out:
# (9976, 11)

# %%
df.shape
# Out:
# (10568, 11)

# %%
df['error_label'].value_counts()
# Out:
# 0    9976
# 1     592
# Name: error_label, dtype: int64

# %%
df_filtered.head(15)
# Out:
#      pid              time operation  operation_label  \
# 0   8703  1525430073780920      read                2
# 1   8703  1525430073781000      read                2
# 2   8703  1525430073781060      read                2
# 3   8703  1525430073781120      read                2
# 4   8703  1525430073781200      read                2
# 5   8703  1525430073781260      read                2
# 6   8703  1525430073781320      read                2
# 7   8703  1525430073781380      read                2
# 8   8703  1525430073781450      read                2
# 9   8703  1525430073781510      read                2
# 10  8703  1525430073781570      read                2
# 11  8703  1525430073781640      read                2
# 12  8703  1525430073781700      read                2
# 13  8703  1525430073781760      read                2
# 14  8703  1525430073781820      read                2
#
#                                                  path  idfile    rs size  \
# 0    \1\0\0\0\377\377\377\377\377\377\377\377\377\...     821  32.0   32
# 1                                            \\\0\0\0     821   4.0    4
# 2                                            \n\0\0\0     821   4.0    4
# 3                                         --version\0       7  10.0   10
# 4                                            \6\0\0\0       7   4.0    4
# 5                                             3.2.1\0       7   6.0    6
# 6                                           \24\0\0\0       7   4.0    4
# 7                               --iface-ip-env-name\0       7  20.0   20
# 8                                             !\0\0\0       7   4.0    4
# 9                 MPIR_CVAR_CH3_INTERFACE_HOSTNAME...       7  33.0   33
# 10                                           \v\0\0\0       7   4.0    4
# 11                                       --hostname\0       7  11.0   11
# 12                                           \6\0\0\0       7   4.0    4
# 13                                            clus5\0       7   6.0    6
# 14                                          \22\0\0\0       7   4.0    4
#
#    error  error_label flag
# 0    NaN            0  NaN
# 1    NaN            0  NaN
# 2    NaN            0  NaN
# 3    NaN            0  NaN
# 4    NaN            0  NaN
# 5    NaN            0  NaN
# 6    NaN            0  NaN
# 7    NaN            0  NaN
# 8    NaN            0  NaN
# 9    NaN            0  NaN
# 10   NaN            0  NaN
# 11   NaN            0  NaN
# 12   NaN            0  NaN
# 13   NaN            0  NaN
# 14   NaN            0  NaN

# %%
df_filtered.drop(columns=['error', 'error_label', 'flag'], inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
    df_filtered.head(15)
# Out:
#      pid              time operation  operation_label  \
# 0   8703  1525430073780920      read                2
# 1   8703  1525430073781000      read                2
# 2   8703  1525430073781060      read                2
# 3   8703  1525430073781120      read                2
# 4   8703  1525430073781200      read                2
# 5   8703  1525430073781260      read                2
# 6   8703  1525430073781320      read                2
# 7   8703  1525430073781380      read                2
# 8   8703  1525430073781450      read                2
# 9   8703  1525430073781510      read                2
# 10  8703  1525430073781570      read                2
# 11  8703  1525430073781640      read                2
# 12  8703  1525430073781700      read                2
# 13  8703  1525430073781760      read                2
# 14  8703  1525430073781820      read                2
#
#                                                  path  idfile    rs size
# 0    \1\0\0\0\377\377\377\377\377\377\377\377\377\...     821  32.0   32
# 1                                            \\\0\0\0     821   4.0    4
# 2                                            \n\0\0\0     821   4.0    4
# 3                                         --version\0       7  10.0   10
# 4                                            \6\0\0\0       7   4.0    4
# 5                                             3.2.1\0       7   6.0    6
# 6                                           \24\0\0\0       7   4.0    4
# 7                               --iface-ip-env-name\0       7  20.0   20
# 8                                             !\0\0\0       7   4.0    4
# 9                 MPIR_CVAR_CH3_INTERFACE_HOSTNAME...       7  33.0   33
# 10                                           \v\0\0\0       7   4.0    4
# 11                                       --hostname\0       7  11.0   11
# 12                                           \6\0\0\0       7   4.0    4
# 13                                            clus5\0       7   6.0    6
# 14                                          \22\0\0\0       7   4.0    4

# %%
# sns.pairplot(df_filtered, vars=['pid', 'idfile', 'rs', 'size'], hue='operation_label')
